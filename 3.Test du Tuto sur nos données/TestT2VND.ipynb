# %% [markdown]
# **Aller au GPU en premier et mettre T4**
#
# **Importer le fichier combined_training_data.spacy dans l'environnement Google Collab afin de pouvoir exécuter ce code**

# %% [markdown]
# **Création du fichier de base config en français pour nos données**

# %%
# !python -m spacy init config base_config.cfg --lang fr --pipeline ner

# %% [markdown]
# **Création du fichier config**

# %%
# !python -m spacy init fill-config base_config.cfg config.cfg

# %% [markdown]
# **Entraînement du modèle sur nos données**

# %%
# !python -m spacy train config.cfg --output ./ --paths.train ./training_data.spacy --paths.dev ./training_data.spacy --gpu-id 0

# %% [markdown]
# **Test du modèle**

# %%
import spacy
nlp_ner = spacy.load("model-best")

doc = nlp_ner("Petite Jeanne a vu sa grand-mère dans le département ")

colors = {"PER": "#F67DE3", "LOC": "#7DF6D9", "MISC":"#FFFFFF"}
options = {"colors": colors}

spacy.displacy.render(doc, style="ent", options= options, jupyter=True)
