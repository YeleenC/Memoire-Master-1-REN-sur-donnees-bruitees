# %%
from google.colab import drive
drive.mount('/content/drive_new')
# Out:
# Mounted at /content/drive_new

# %%
from pathlib import Path

dossier_spacy = Path("/content/drive_new/MyDrive/Colab Notebooks/MemoireTestC/JSON_entrainementC1")
fichiers_spacy = list(dossier_spacy.glob("*.spacy"))
print(fichiers_spacy)
# Out:
# [PosixPath('/content/drive_new/MyDrive/Colab Notebooks/MemoireTestC/JSON_entrainementC1/Corpus_Entrainement_Enrichi.spacy'), PosixPath('/content/drive_new/MyDrive/Colab Notebooks/MemoireTestC/JSON_entrainementC1/Corpus_25p.spacy'), PosixPath('/content/drive_new/MyDrive/Colab Notebooks/MemoireTestC/JSON_entrainementC1/Corpus_REF.spacy'), PosixPath('/content/drive_new/MyDrive/Colab Notebooks/MemoireTestC/JSON_entrainementC1/Corpus_50p.spacy'), PosixPath('/content/drive_new/MyDrive/Colab Notebooks/MemoireTestC/JSON_entrainementC1/Corpus_Tesseract.spacy'), PosixPath('/content/drive_new/MyDrive/Colab Notebooks/MemoireTestC/JSON_entrainementC1/Corpus_Kraken.spacy'), PosixPath('/content/drive_new/MyDrive/Colab Notebooks/MemoireTestC/JSON_entrainementC1/Corpus_75p.spacy')]

# %%
# !pip install -U spacy

# %%
# !python -m spacy init config "/content/drive_new/MyDrive/Colab Notebooks/MemoireTestC/75/config_75.cfg" \
  --lang fr --pipeline ner --optimize efficiency
# Out:
# ⚠ To generate a more effective transformer-based config (GPU-only),
# install the spacy-transformers package and re-run this command. The config
# generated now does not use transformers.
# ℹ Generated config template specific for your use case
# - Language: fr
# - Pipeline: ner
# - Optimize for: efficiency
# - Hardware: CPU
# - Transformer: None
# ✔ Auto-filled config with all values
# ✔ Saved config
# /content/drive_new/MyDrive/Colab Notebooks/MemoireTestC/75/config_75.cfg
# You can now add your data and train your pipeline:
# python -m spacy train config_75.cfg --paths.train ./train.spacy --paths.dev ./dev.spacy

# %%
import os
import shutil

# %%
# Chemin fichier .spacy existant
fichier_spacy = "/content/drive_new/MyDrive/Colab Notebooks/MemoireTestC/JSON_entrainementC1/Corpus_75p.spacy"

# Dossier de sortie pour ce modèle tok2vec
dossier_donnees = "/content/drive_new/MyDrive/Colab Notebooks/MemoireTestC/75"
os.makedirs(dossier_donnees, exist_ok=True)

# Copier deux fois le même fichier (train et dev identiques pour l'instant)
shutil.copy(fichier_spacy, os.path.join(dossier_donnees, "train.spacy"))
shutil.copy(fichier_spacy, os.path.join(dossier_donnees, "dev.spacy"))
# Out:
# '/content/drive_new/MyDrive/Colab Notebooks/MemoireTestC/75/dev.spacy'

# %%
# !python -m spacy train "/content/drive_new/MyDrive/Colab Notebooks/MemoireTestC/75/config_75.cfg" \
  --output "/content/drive_new/MyDrive/Colab Notebooks/MemoireTestC/75" \
  --paths.train "/content/drive_new/MyDrive/Colab Notebooks/MemoireTestC/75/train.spacy" \
  --paths.dev "/content/drive_new/MyDrive/Colab Notebooks/MemoireTestC/75/dev.spacy" \
 # --gpu-id 0
# Out:
# ℹ Saving to output directory: /content/drive_new/MyDrive/Colab
# Notebooks/MemoireTestC/75
# ℹ Using CPU
#
# =========================== Initializing pipeline ===========================
# ✔ Initialized pipeline
#
# ============================= Training pipeline =============================
# ℹ Pipeline: ['tok2vec', 'ner']
# ℹ Initial learn rate: 0.001
# E    #       LOSS TOK2VEC  LOSS NER  ENTS_F  ENTS_P  ENTS_R  SCORE
# ---  ------  ------------  --------  ------  ------  ------  ------
#   0       0          0.00   2469.77    0.00    0.00    0.00    0.00
#  33     200        761.85  53428.67   99.30   99.41   99.19    0.99
#  66     400        286.50    938.02   99.41   99.26   99.56    0.99
# 100     600        196.93    626.34   99.59   99.56   99.63    1.00
# 133     800        165.63    543.98   99.63   99.41   99.85    1.00
