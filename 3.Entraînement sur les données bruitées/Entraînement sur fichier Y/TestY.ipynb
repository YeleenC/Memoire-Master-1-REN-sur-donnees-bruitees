# %%
from google.colab import drive
drive.mount('/content/drive_new')
# Out:
# Mounted at /content/drive_new

# %%
from pathlib import Path

dossier_spacy = Path("/content/drive_new/MyDrive/Colab Notebooks/MemoireTestY/JSON entraînementY")
fichiers_spacy = list(dossier_spacy.glob("*.spacy"))
print(fichiers_spacy)
# Out:
# [PosixPath('/content/drive_new/MyDrive/Colab Notebooks/MemoireTestY/JSON entraînementY/ensemble_complet.spacy'), PosixPath('/content/drive_new/MyDrive/Colab Notebooks/MemoireTestY/JSON entraînementY/ensemble_25pourcent.spacy'), PosixPath('/content/drive_new/MyDrive/Colab Notebooks/MemoireTestY/JSON entraînementY/ensemble_REF.spacy'), PosixPath('/content/drive_new/MyDrive/Colab Notebooks/MemoireTestY/JSON entraînementY/ensemble_50pourcent.spacy'), PosixPath('/content/drive_new/MyDrive/Colab Notebooks/MemoireTestY/JSON entraînementY/ensemble_Tesseract.spacy'), PosixPath('/content/drive_new/MyDrive/Colab Notebooks/MemoireTestY/JSON entraînementY/ensemble_Kraken.spacy'), PosixPath('/content/drive_new/MyDrive/Colab Notebooks/MemoireTestY/JSON entraînementY/ensemble_75pourcent.spacy')]

# %%
# !pip install -U spacy

# %%
# !python -m spacy init config "/content/drive_new/MyDrive/Colab Notebooks/MemoireTestY/Tesseract/config_Tesseract.cfg" \
  --lang fr --pipeline ner --optimize efficiency
# Out:
# ⚠ To generate a more effective transformer-based config (GPU-only),
# install the spacy-transformers package and re-run this command. The config
# generated now does not use transformers.
# ℹ Generated config template specific for your use case
# - Language: fr
# - Pipeline: ner
# - Optimize for: efficiency
# - Hardware: CPU
# - Transformer: None
# ✔ Auto-filled config with all values
# ✔ Saved config
# /content/drive_new/MyDrive/Colab
# Notebooks/MemoireTestY/Tesseract/config_Tesseract.cfg
# You can now add your data and train your pipeline:
# python -m spacy train config_Tesseract.cfg --paths.train ./train.spacy --paths.dev ./dev.spacy

# %%
import os
import shutil

# %%
# Chemin fichier .spacy existant
fichier_spacy = "/content/drive_new/MyDrive/Colab Notebooks/MemoireTestY/JSON entraînementY/ensemble_Tesseract.spacy"

# Dossier de sortie pour ce modèle tok2vec
dossier_donnees = "/content/drive_new/MyDrive/Colab Notebooks/MemoireTestY/Tesseract"
os.makedirs(dossier_donnees, exist_ok=True)

# Copier deux fois le même fichier (train et dev identiques pour l'instant)
shutil.copy(fichier_spacy, os.path.join(dossier_donnees, "train.spacy"))
shutil.copy(fichier_spacy, os.path.join(dossier_donnees, "dev.spacy"))
# Out:
# '/content/drive_new/MyDrive/Colab Notebooks/MemoireTestY/Tesseract/dev.spacy'

# %%
# !python -m spacy train "/content/drive_new/MyDrive/Colab Notebooks/MemoireTestY/Tesseract/config_Tesseract.cfg" \
  --output "/content/drive_new/MyDrive/Colab Notebooks/MemoireTestY/Tesseract" \
  --paths.train "/content/drive_new/MyDrive/Colab Notebooks/MemoireTestY/Tesseract/train.spacy" \
  --paths.dev "/content/drive_new/MyDrive/Colab Notebooks/MemoireTestY/Tesseract/dev.spacy" \
  --gpu-id 0
# Out:
# ℹ Saving to output directory: /content/drive_new/MyDrive/Colab
# Notebooks/MemoireTestY/Tesseract
# ℹ Using GPU: 0
#
# =========================== Initializing pipeline ===========================
# ✔ Initialized pipeline
#
# ============================= Training pipeline =============================
# ℹ Pipeline: ['tok2vec', 'ner']
# ℹ Initial learn rate: 0.001
# E    #       LOSS TOK2VEC  LOSS NER  ENTS_F  ENTS_P  ENTS_R  SCORE
# ---  ------  ------------  --------  ------  ------  ------  ------
#   0       0          0.00   3215.80    0.00    0.00    0.00    0.00
# 100     200       2300.86  61710.79  100.00  100.00  100.00    1.00
# 200     400        396.23    130.98  100.00  100.00  100.00    1.00
# 300     600        248.82     54.22  100.00  100.00  100.00    1.00
# 400     800        326.97     41.91  100.00  100.00  100.00    1.00
# 500    1000        469.49     54.36  100.00  100.00  100.00    1.00
# 600    1200        416.20     53.38  100.00  100.00  100.00    1.00
# ...
