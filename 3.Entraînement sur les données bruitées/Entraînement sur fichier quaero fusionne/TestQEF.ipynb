# %%
from google.colab import drive
drive.mount('/content/drive_new')
# Out:
# Drive already mounted at /content/drive_new; to attempt to forcibly remount, call drive.mount("/content/drive_new", force_remount=True).

# %%
from pathlib import Path

dossier_spacy = Path("/content/drive_new/MyDrive/Colab Notebooks/MemoireTestQEF/quaero_enrichi")
fichiers_spacy = list(dossier_spacy.glob("*.spacy"))
print(fichiers_spacy)
# Out:
# [PosixPath('/content/drive_new/MyDrive/Colab Notebooks/MemoireTestQEF/quaero_enrichi/Corpus_Entrainement_Enrichi_75p.spacy'), PosixPath('/content/drive_new/MyDrive/Colab Notebooks/MemoireTestQEF/quaero_enrichi/Corpus_Entrainement_Enrichi_Tesseract.spacy'), PosixPath('/content/drive_new/MyDrive/Colab Notebooks/MemoireTestQEF/quaero_enrichi/Corpus_Entrainement_Enrichi_avec_Quaero_fusioné.spacy'), PosixPath('/content/drive_new/MyDrive/Colab Notebooks/MemoireTestQEF/quaero_enrichi/Corpus_Entrainement_Enrichi_REF.spacy'), PosixPath('/content/drive_new/MyDrive/Colab Notebooks/MemoireTestQEF/quaero_enrichi/Corpus_Entrainement_Enrichi_Kraken.spacy'), PosixPath('/content/drive_new/MyDrive/Colab Notebooks/MemoireTestQEF/quaero_enrichi/Corpus_Entrainement_Enrichi_50p.spacy'), PosixPath('/content/drive_new/MyDrive/Colab Notebooks/MemoireTestQEF/quaero_enrichi/Corpus_Entrainement_Enrichi_25p.spacy')]

# %%
# !pip install -U spacy

# %%
# !python -m spacy init config "/content/drive_new/MyDrive/Colab Notebooks/MemoireTestQEF/Tesseract/config_Tesseract.cfg" \
  --lang fr --pipeline ner --optimize efficiency
# Out:
# ✘ The provided output file already exists. To force overwriting the
# config file, set the --force or -F flag.

# %%
import os
import shutil

# %%
# Chemin fichier .spacy existant
fichier_spacy = "/content/drive_new/MyDrive/Colab Notebooks/MemoireTestQEF/quaero_enrichi/Corpus_Entrainement_Enrichi_Tesseract.spacy"

# Dossier de sortie pour ce modèle tok2vec
dossier_donnees = "/content/drive_new/MyDrive/Colab Notebooks/MemoireTestQEF/Tesseract"
os.makedirs(dossier_donnees, exist_ok=True)

# Copier deux fois le même fichier (train et dev identiques pour l'instant)
shutil.copy(fichier_spacy, os.path.join(dossier_donnees, "train.spacy"))
shutil.copy(fichier_spacy, os.path.join(dossier_donnees, "dev.spacy"))
# Out:
# '/content/drive_new/MyDrive/Colab Notebooks/MemoireTestQEF/Tesseract/dev.spacy'

# %%
# !python -m spacy train "/content/drive_new/MyDrive/Colab Notebooks/MemoireTestQEF/Tesseract/config_Tesseract.cfg" \
  --output "/content/drive_new/MyDrive/Colab Notebooks/MemoireTestQEF/Tesseract" \
  --paths.train "/content/drive_new/MyDrive/Colab Notebooks/MemoireTestQEF/Tesseract/train.spacy" \
  --paths.dev "/content/drive_new/MyDrive/Colab Notebooks/MemoireTestQEF/Tesseract/dev.spacy" \
  #--gpu-id 0
# Out:
# ℹ Saving to output directory: /content/drive_new/MyDrive/Colab
# Notebooks/MemoireTestQEF/Tesseract
# ℹ Using CPU
#
# =========================== Initializing pipeline ===========================
# ✔ Initialized pipeline
#
# ============================= Training pipeline =============================
# ℹ Pipeline: ['tok2vec', 'ner']
# ℹ Initial learn rate: 0.001
# E    #       LOSS TOK2VEC  LOSS NER  ENTS_F  ENTS_P  ENTS_R  SCORE
# ---  ------  ------------  --------  ------  ------  ------  ------
#   0       0          0.00   3361.30    0.00    0.00    0.00    0.00
