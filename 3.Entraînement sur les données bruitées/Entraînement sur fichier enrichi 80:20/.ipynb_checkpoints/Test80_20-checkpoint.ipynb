# %%
from google.colab import drive
drive.mount('/content/drive_new')

# %%
# Fichiers d'entrée
train_spacy = "/content/drive_new/MyDrive/Colab Notebooks/MémoireTest80_20/JSON_TrainTest/Corpus_80p.spacy"
dev_spacy = "/content/drive_new/MyDrive/Colab Notebooks/MémoireTest80_20/JSON_TrainTest//Corpus_20p.spacy"

# %%
import os
import shutil

# Dossier de sortie pour ce modèle
dossier_donnees = "/content/drive_new/MyDrive/Colab Notebooks/MémoireTest80_20/80_20"
os.makedirs(dossier_donnees, exist_ok=True)

# Copier les bons fichiers
shutil.copy(train_spacy, os.path.join(dossier_donnees, "train.spacy"))
shutil.copy(dev_spacy, os.path.join(dossier_donnees, "dev.spacy"))

# %%
# !pip install -U spacy

# %%
# !python -m spacy init config "/content/drive_new/MyDrive/Colab Notebooks/MémoireTest80_20/80_20/config_8020.cfg" \
  --lang fr --pipeline ner --optimize efficiency

# %%
import os
import shutil

# Dossier de sortie pour ce modèle
dossier_donnees = "/content/drive_new/MyDrive/Colab Notebooks/MémoireTest80_20/80_20"
os.makedirs(dossier_donnees, exist_ok=True)

# Copier les bons fichiers
shutil.copy(train_spacy, os.path.join(dossier_donnees, "train.spacy"))
shutil.copy(dev_spacy, os.path.join(dossier_donnees, "dev.spacy"))

# %%
# !python -m spacy train "/content/drive_new/MyDrive/Colab Notebooks/MémoireTest80_20/80_20/config_8020.cfg" \
  --output "/content/drive_new/MyDrive/Colab Notebooks/MémoireTest80_20/80_20" \
  --paths.train "/content/drive_new/MyDrive/Colab Notebooks/MémoireTest80_20/80_20/train.spacy" \
  --paths.dev "/content/drive_new/MyDrive/Colab Notebooks/MémoireTest80_20/80_20/dev.spacy" \
  --gpu-id 0
